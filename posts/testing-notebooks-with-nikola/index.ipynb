# %% [markdown]
# # Testing posts with Jupyter notebooks in Nikola

# %% [markdown]
# ### This post is just a quick exploration of the capabilities of [Nikola](https://getnikola.com/handbook.html) with jupyter notebooks
#
# <!-- TEASER_END -->

# %% [markdown]
# ### this for inline display of matplotlib plots

# %%
# %matplotlib inline

# %% [markdown]
# ### some imports

# %%
from matplotlib import pyplot as plt 
import numpy as np
import pandas as pd

# %% [markdown]
# ### testing inline plots

# %%
np.random.seed(42)

# %%
x = np.random.randn(1000)

# %%
x = np.cumsum(x)

# %%
df = pd.DataFrame(x, columns=['x'], index=pd.date_range(start='2000-1-1', periods=len(x)))

# %%
df.plot(legend=None, figsize=(10, 6), grid=True);

# %% [markdown]
# ### equations with MathJax

# %% [markdown]
# $$e^x=\sum_{i=0}^\infty \frac{1}{i!}x^i$$

# %% [markdown]
# ### pandas dataframes

# %%
df.head()
# Out:
#                    x
# 2000-01-01  0.496714
# 2000-01-02  0.358450
# 2000-01-03  1.006138
# 2000-01-04  2.529168
# 2000-01-05  2.295015
